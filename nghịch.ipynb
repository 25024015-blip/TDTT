# %%
def loi_chao_hoi() :
    print("xin chào tôi là thằng gấu")
loi_chao_hoi()
# Out:
# xin chào tôi là thằng gấu

# %% [markdown]
# # CÁCH 1 DÙNG DEF

# %%
def loi_chao(ten) : 
    print(f"xin chào tôi là",ten)
loi_chao("gấu")
# Out:
# xin chào tôi là gấu

# %% [markdown]
# # CÁCH 2 DÙNG DEF

# %%
def dien_tich(dai,rong):
    kq = dai*rong
    return kq 
a = float(input()) 
b = float(input())
           
print("diện tích hình chữ nhật là",dien_tich(a,b))
# Out:
# diện tích hình chữ nhật là 20.0

# %% [markdown]
# # CÁCH 3 DÙNG DEF

# %%
def thong_tin(ten,qg = "việt nam"):
    print(f"xin chào tên tôi là {ten},tôi đến từ quốc gia {qg}")
thong_tin("gấu")    
thong_tin("gấu","cam pu chia"),
thong_tin(1)
# Out:
# xin chào tên tôi là gấu,tôi đến từ quốc gia việt nam
# xin chào tên tôi là gấu,tôi đến từ quốc gia cam pu chia
# xin chào tên tôi là 1,tôi đến từ quốc gia việt nam

# %%
def loi ():
    print("chúc mừng sinh nhât")
    print("gấu") 
    print("gấu bị 0 điểm") 
loi()
# Out:
# chúc mừng sinh nhât
# gấu
# gấu bị 0 điểm

# %% [markdown]
# # CÁCH 4 DÙNG DEF

# %%
n = int(input("hãy nhập một số bất kì")) #cách sử dụng căn bản và cơ bản của câu lệnh rẽ nhánh if 
if (n<=30 and n>=15):
    print("chuẩn ")
else :
    print("sai")
# Out:
# sai

# %%
# print("hello",   end = " ")
# print("nam") 
ngay = 2
thang = 9
nam = 2007
print(f"{ngay}/ {thang}/ {nam}")
# Out:
# 2/ 9/ 2007

# %% [markdown]
# ## W2A2
# tìm hiểu hàm input

# %%
m = int(input()) 
n =str(input()) 
print(f"kiểu chuỗi", n , end = ",")
print(f"kiểu số nguyên ",m)
# Out:
# kiểu chuỗi 10,kiểu số nguyên  10

# %%
a = float(input("hãy nhập vào một số nguyên")) 
b = float(input("hãy nhập vào một số nguyên"))
kq = a+b 
print(int(kq))
kq = a//b
print()
# Out:
# 7

# %% [markdown]
# # W2A3 [ModAndDiv]
# Viết chương trình nhận vào hai số nguyên a, b từ bàn phím. In ra tổng, hiệu, tích, phần
# nguyên, phần dư và kết quả chia thực của phép chia a cho b (lấy đến 2 chữ số phần thập
# phân) theo định dạng đúng của output

# %%
# a = float(input()) 
# b = float(input()) 
# print("tổng của chúng là",a+b) 
# print(f"hiệu của chúng là, {a+b:.2f}") 
# a = float(input()) 
# b = float(input())
a,b =map(float,input("nhập giá trị").split())
print(a+b)
# Out:
# 7.0
