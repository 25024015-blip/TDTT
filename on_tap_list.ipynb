# %% [markdown]
# hãy nhập vào 1 list số nguyên yêu cầu loại bỏ các phần tử giống nhau nhưng vẫn giữ nguyên đúng thứ tự định dạng và hãy in ra một list kết quả lưu ý lưu đúng định dạng

# %%
data=list(map(int,input().split()))
kq=[]
for i in data:
    if i not in kq:
        kq.append(i)
print(kq)
# Out:
# [4, 5, 6, 7]

# %% [markdown]
# nhập vào một dòng số nguyên tính tổng tích lũy số nguyên đó đến vị trí thứ k lưu ý giữ nguyên vị trí

# %%
data=list(map(int,input().split()))
k=int(input())
tong=0 
for i in range(k+1): #đây là cách gọi thẳng giá trị ra khi đã biết vị trí
    tong+=data[i]
print(tong)    # đây là một bài toán cộng dựa vào vị trí trên giá trị nhập được chứ không phải một bài toán quét hàm range theo kiểu cộng tích lũy
# Out:
# 15

# %% [markdown]
# nhập vào một tuple số nguyên trên một dòng và một số nguyên k ở dòng kế ,yêu cầu in ra một tuple xoay k vị trí yêu cầu không thay đổi vị trí và cách sắp xếp

# %%
data=tuple(map(int,input().split()))
k=int(input())
n=len(data)
if n>0: 
    k=k%n #phòng trường hợp độ dài của data nhỏ hơn số lần k xoay (chuẩn hóa k trong trường hợp k lớn hơn n)
    kq=data[k:]+data[:k]
    print(tuple(kq)) 
else:
    print(*data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 data=tuple(map(int,input().split()))
# ----> 2 k=int(input())
#       3 n=len(data)
#       4 if n>0:
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# nhập vào một dòng gồm các key và value cách nhau bởi dấu cách ,tạo một dictionary ánh xạ mỗi key ra list các value theo thứ tự xuất hiện ,nếu key lặp lại thêm vào list của key đó

# %%
data=input().split()
kq={}
for i in range(0,len(data),2): 
    key=data[i]
    value=data[i+1]
    if key in kq :
        kq[key].append(value) * nếu đã có key thì nhét vào cuối danh sách list 
    else:
        kq[key]=[value] *còn không thì phải tạo ra một danh sách mới chứa các value đó 
print(kq)
# Out:
#   Cell In[12], line 3
#     for i in range(0,len(data),2):
#                                   ^
# _IncompleteInputError: incomplete input

# %%
# cách 2 nếu như định dạng nhập vào tồn tại dấu :
data=input().split() 
kq={}
for i in data:
    key,value=i.split(":")
    if key in kq:
        kq[key].append(value)
    else:
        kq[key]=[value]
print(kq)

# %% [markdown]
# viết chương trình nhập vào một danh sách số nguyên sau đó in ra tổng

# %%
data=list(map(int,input().split()))
tong=0 
for i in data: 
    tong+=i 
print(tong)
# Out:
# 21

# %% [markdown]
# viết chương  trình nhâph vào một tuple ,in ra phần từ đầu và phần tử cuối cũng như tuple đảo ngược

# %%
data=tuple(map(str,input().split()))
print(f"{data[0]},{data[-1]},{data[::-1]}")
# Out:
# nam,nam,('nam',)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# viết chương trình nhập vào một list các chuỗi sau đó đếm số lần xuất hiện của từng chuỗi và in nó ra sau đó cho vào một dict

# %%
data=input().split() 
kq={} 
for i in data: 
    if i in  kq:
        kq[i]+=1 
    else:
        kq[i]=1 
print(kq)
# Out:
# {'3': 1, '4': 1, '5': 2}

# %%
data=input().split()
kq={}
for i in data:
    if i in kq:
        kq[i]+=1 
    else:
        kq[i]=1 
print(kq)

# %% [markdown]
# viết chương trình nhập vào hai dictionary ,sau đó gộp lại thành 1 dictionanry mới trong đó nếu một key xuất hiện trong cả hai dict giá trị sẽ được cộng lại ,nếu chỉ có trong một dict thì giữ nguyên ,in ra dict mới theo thứ stuwj tăng dần của key

# %%
dict1=eval(input())
dict2=eval(input())
kq=dict1.copy()
for key,value in dict2.items():
    if key in kq:
        kq[key]=kq[key]+dict2[key]
    else:  
        kq[key]=dict2[key]
print(dict(sorted(kq.items)))
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[9], line 1
#     dict1=eval(input())
#
#   File <string>:1
#     1 nam 2 báo
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# W6A10
# Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên
# dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là
# một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh
# sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được
# sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple.

# %%
data=list(map(int,input().split()))
k=int(input()) 
kq=set()
for i in range (len(data)):
    for j in range(i+1,len(data)):
        if data[i]+data[j]==k: 
            kq.add((data[i],data[j]))
print(list(sorted(kq)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       5     for j in range(i+1,len(data)+1):
#       6         if i+j==k:
# ----> 7             kq.add(i,j)
#       8 print(kq)
#
# TypeError: set.add() takes exactly one argument (2 given)

# %% [markdown]
# W6A11
# [Tách số chẵn và lẻ từ tuple]
# Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa
# tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên
# thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
data=tuple(map(int,input().split()))
kq1=[]
kq2=[]
for i in data: 
    if i%2==0: 
        kq1.append(i)
    else:
        kq2.append(i)
kq11=tuple(kq1) 
kq22=tuple(kq2)
print(f"{kq11}\n{kq22}")
# Out:
#   Cell In[13], line 5
#     if i%2==0:
#               ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# W6A12
# [Tìm phần tử xuất hiện nhiều nhất]
# Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong
# list. Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ
# nhất trong số đó.

# %%
data=list(map(int,input().split()))
data1=sorted(data)
print(max(data1,key=data1.count))
# Out:
# 2

# %% [markdown]
# W6A13
# [Đảo ngược key và value của dictionary]
# Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo
# một dictionary mới bằng cách đảo ngược key và value của dictionary ban
# đầu. In ra dictionary mới.

# %%
data=eval(input())
kq={} 
for key,value in data.items():
    kq[value]=key 
print(kq)

# %% [markdown]
# W6A14 [Giao của hai danh sách]
# Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các
# phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các
# phần tử chung đó, không trùng lặp.

# %%
data=list(map(int,input().split()))
data1=list(map(int,input.split())) 
print(list(set(data)&set(data1)))

# %% [markdown]
# W6A15
# [Lọc dictionary theo giá trị]
# Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số
# nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp
# key-value từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary
# mới.

# %%
data=eval(input())
k=int(input())
kq={}
for key,value in data.items():
    if data[key]>k: 
        kq[key]=value
print(kq)
# Out:
#   Cell In[15], line 5
#     if kq[key]>k:
#                  ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# W6A1
# Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng
# giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.
# Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
data=list(map(int,input().split()))
kq=[]
for i in data:
    if i not in kq:
        kq.append(i)
print(kq)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# W6A2
# Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu
# tới vị trí i), giữ nguyên thứ tự

# %%
data=list(map(int,input().split())) # bài tập tính tổng đến vị trí thứ i
i=int(input()) 
tong=0 
for k in range(i+1):
    tong+=data[k]
print(tong)
# Out:
# 5

# %% [markdown]
# W6A3
# Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple
# sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp
# xếp.)

# %%
data=tuple(map(int,input().split()))
k=int(input())
n=len(data) 
if n>0:
    k=k%n #chuẩn hóa trong trường hợp chiều dài của data nhỏ hơn k vị trí 
    kq=data[k:]+data[:k]
    print(kq) 
else:
    print(*data)
# Out:
# (3, 3, 3)

# %% [markdown]
# Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo
# dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key
# lặp lại, thêm vào list của key đó

# %%
data=input().split() # input là TOAN 7 TOAN 8 LI 9 HOA 10
kq={}
for i in range(0,len(data),2): 
    key=data[i]
    value=data[i+1]
    if key in kq:
        kq[key].append(value)
    else:
        kq[key]=[value] # tạo một kq có key và tạo hẳn một danh sách phù hợp
print(kq)
# Out:
# {'Toan': ['7', '8'], 'LI': ['9'], 'Hoa': ['10']}

# %%
data=input().split() # NHẬP CHUỖI NÊN CÓ Thể gọi giá trị bằng cách ngoặc vuông 
kq={} 
for i in range(0,len(data),2):
    key=data[i]
    value=[i+1]
    if key in kq:
        kq[key].append(value)
    else:
        kq[key]=[value]
print(kq)
# Out:
# {'TOAN': [[1], [3]], 'LI': [[5]], 'HOA': [[7]]}

# %% [markdown]
# W6A6
# Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng

# %%
data=list(map(int,input().split()))
tong=0 
for i in data:
    tong+=i 
print(tong)
# Out:
# 9

# %% [markdown]
# W6A7
# Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và tuple đảo ngược

# %%
data=tuple(map(str,input().split()))
print(f"{data[0]},{data[-1]},{data[::-1]}")
# Out:
# 2,5,('5', '4', '4', '3', '2')

# %% [markdown]
# W6A8
# Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện
# của từng chuỗi và lưu vào dict

# %%
data=input().split()
kq={}
for i in data:
    if i in kq:
        kq[i]+=1
    else:
        kq[i]=1  
print(kq)
# Out:
# {'toan': 2, 'li': 1, 'hoa': 1, 'sinh': 1}

# %%
data=input().split()
kq={}
for i in data:
    if i in kq:
        kq[i]+=1 
    else:
        kq[i]=1 
print(kq)
# Out:
# {'lí': 3, 'hoa': 1}

# %% [markdown]
# W6A9
# Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một
# dictionary mới trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ
# được cộng lại, nếu chỉ có trong một dict thì giữ nguyên. In ra dictionary mới
# theo thứ tự từ điển tăng dần của key.

# %%
dict1=eval(input()) # đây là nhập theo kiểu dict 
dict2=eval(input())
kq=dict1.copy()
for key,value in dict2.items():
    if key in kq:
        kq[key]=kq[key]+dict2[key]
    else:
        kq[key]=dict2[key] 
print(dict(sorted(kq.items())))   # items tức là bản thân thêm cả key và value
# Out:
# {'a': 5, 'b': 3, 'j': 45, 'm': 3}

# %% [markdown]
# W6A10
# Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên
# dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là
# một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh
# sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được
# sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple.

# %%
data=list(map(int,input().split())) 
k=int(input())
kq=set()
for i in range(len(data)):
    for j in range(i+1,len(data)):
        if data[i]+data[j]==k:
            kq.add((data[i],data[j]))
print(list(sorted(kq)))

# %% [markdown]
# W6A11
# [Tách số chẵn và lẻ từ tuple]
# Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa
# tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên
# thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
data=list(map(int,input().split()))
kq1=[]
kq2=[]
for i in data:
    if i%2==0: 
        kq1.append(i)
    else:    
        kq2.append(i)
kq11=tuple(kq1)
kq22=tuple(kq2)
print(f"{kq11}\n{kq22}")
# Out:
# (2, 4)
# (3, 5)

# %% [markdown]
# W6A12
# [Tìm phần tử xuất hiện nhiều nhất]
# Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong
# list. Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ
# nhất trong số đó.

# %%
data=list(map(int,input().split())) 
data1=sorted(data)
print(max(data1,key=data1.count))
# Out:
# 5

# %% [markdown]
# W6A13
# [Đảo ngược key và value của dictionary]
# Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo
# một dictionary mới bằng cách đảo ngược key và value của dictionary ban
# đầu. In ra dictionary mới.

# %%
data=eval(input()) 
kq={}
for key,value in data.items(): 
    kq[value]=key 
print(kq)
# Out:
# {1: 'nam'}

# %% [markdown]
# W6A14 [Giao của hai danh sách]
# Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các
# phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các
# phần tử chung đó, không trùng lặp.

# %%
list1=list(map(int,input().split()))
list2=list(map(int,input().split()))
print(f"{set(list1)&set(list2)}")
# Out:
# {4, 5}

# %% [markdown]
# W6A15
# [Lọc dictionary theo giá trị]
# Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số
# nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp
# key-value từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary
# mới.

# %%
data=eval(input())
k=int(input()) 
kq={}
for key,value in data.items():
    if data[key]>k:
        kq[key]=value 
print(kq)

# %% [markdown]
# W6A16
# Nhâ ̣p vào mảng n hàng, m cột số nguyên. In lại mảng ra màn hình như ma ̣
# trận hai chiều, định dạng mỗi phần tử 4 vị trí căn phải

# %%
n,m=map(int,input().split())
matrix=[]
for i in range(n):   
    oneray=list(map(int,input().split())) 
    matrix.append(oneray)
for dong in matrix:
    for element in dong: 
        print('{:>4}'.format(element),end=" ")
    print()
# Out:
#    2    3    4
#    5    6    7

# %% [markdown]
# W6A17
# Nhập vào mảng vuông 2 chiều n hàng, n cột, in ra đường chéo chính và đường chéo phụ của mảng

# %%
n=int(input()) 
matrix=[]
for i in range(n):
    oneray=list(map(int,input().split()))
    matrix.append(oneray)
for i in range(n):    
    print(matrix[i][i],end=" ")
print()
for i in range(n):
    print(matrix[i][n-1-i],end=" ")
print()
# Out:
# 2 5
# 3 4

# %% [markdown]
# Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng giữ
# nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.
# Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
data=list(map(int,input().split()))
kq=[] 
for i in data:
    if i not in kq:
        kq.append(i)
print(kq)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị
# trí i), giữ nguyên thứ tự

# %%
data=list(map(int,input().split()))
i=int(input())
tong=0 
kq=[]
for k in range(i+1): # quét qua các giá trị đến vị trí i xong cứ cộng đến đâu thêm vào cuối của kq
    tong+=data[k] 
    kq.append(tong)
print(kq)
# Out:
# [-1, 0, -1, 0]

# %% [markdown]
# Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple
# sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp
# xếp.)

# %%
data=tuple(map(int,input().split())) # một tuple có xoay được hay không nó còn phụ thuộc vào độ dài mà tuple nhập vào
k=int(input()) 
n=len(data)
if n>0: 
    k=k%n # đây chính là xét trường hợp độ dài data nhỏ hơn n 
    kq=data[k:]+data[:k]
    print(kq)
else:
    print(*data)
# Out:
# (3, 4, 5, 1, 2)

# %% [markdown]
# Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo
# dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key lặp
# lại, thêm vào list của key đó

# %%
data=input().split() # cách nhập xử lí theo chuỗi, lưu ý đề bài đầu vào nó có dấu 2 chấm
kq={}
for i in data:
    chuoi=i.split(":") # xử lí dấu 2 chấm
    for j in range(0,len(chuoi),2):
        key=chuoi[j]
        value=chuoi[j+1]
        if key in kq:
            kq[key].append(value) 
        else:
            kq[key]=[value]
print(kq)
# Out:
# {'a': ['1', '3'], 'b': ['2']}

# %% [markdown]
# Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ..., 'zeros':
# ...} (đếm số >0, <0, =0)

# %%
data=input().split()
a=0
b=0
c=0
for i in data: 
    i=int(i)
    if i >0:
        a+=1
    elif i<0:
        b+=1 
    elif i==0: 
        c+=1 
print(f"'positives':{a},'negatives':{b},'zeros':{c}")
# Out:
# 'positives':2,'negatives':2,'zeros':3

# %%
# cách 2:
data=input().split()
kq={'positives':0,'negatives':0,'zeros':0} # lưu ý cách nhau bằng dấu 2 chấm để còn phân biệt key và value
for i in data:
    i=int(i)
    if i>0: 
        kq['positives']+=1
    elif i<0:
        kq['negatives']+=1
    elif i==0: 
        kq['zeros']+=1
print(kq)
# Out:
# {'positives': 2, 'negatives': 2, 'zeros': 3}

# %% [markdown]
# Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số
# trong list đó.

# %%
data=list(map(int,input().split()))
tong=0 
for i in data: 
    tong+=i 
print(tong)
# Out:
# 6

# %% [markdown]
# Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và tuple đảo
# ngược

# %%
data=tuple(map(str,input().split()))
print(f"{data[0]} {data[-1]} {data[::-1]}")
# Out:
# 5 4 ('4', '1', '7', '2', '8', '5')

# %% [markdown]
# Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện của từng
# chuỗi và lưu vào dictionary.

# %%
data=input().split()
kq={} 
for i in data: 
    if i in kq:  
        kq[i]+=1
    else:
        kq[i]=1
print(kq)
# Out:
# {'apple': 2, 'banana': 1}

# %% [markdown]
# Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một dictionary mới
# trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ được cộng lại, nếu chỉ có
# trong một dict thì giữ nguyên. In ra dictionary mới theo thứ tự từ điển tăng dần của
# key.

# %%
dict1 = eval(input())
dict2 = eval(input())
kq=dict2.copy() 
for key,value in dict1.items():
    if key in kq:
        kq[key]=kq[key]+dict1[key]
    else:
        kq[key]=dict1[key]
print(dict(sorted(kq.items())))
# Out:
# {'a': 3}

# %% [markdown]
# Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra
# list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple
# có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của
# số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên
# trong tuple.

# %%
data=list(map(int,input().split()))
k=int(input())
kq=set()
for i in range(len(data)):
    for j in range(i+1,len(data)):
        if data[i]+data[j]==k:
            kq.add((data[i],data[j]))
print(list(sorted(kq)))
# Out:
# [(1, 5), (2, 4)]

# %% [markdown]
# [Tách số chẵn và lẻ từ tuple]
# Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa
# tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên
# thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
data=list(map(int,input().split()))
kq1=[]
kq2=[]
for i in data:
    if i%2==0:
        kq1.append(i)
    else:
        kq2.append(i)
kq11=tuple(kq1)
kq22=tuple(kq2)
print(f"{kq11}\n{kq22}")
# Out:
# (10, 2, 8, 4, 6)
# (1, 9, 3, 7, 5)

# %% [markdown]
# [Tìm phần tử xuất hiện nhiều nhất]
# Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list.
# Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ nhất
# trong số đó.

# %%
data=list(map(int,input().split())) 
data1=sorted(data)
print(max(data1,key=data1.count))
# Out:
# 2

# %% [markdown]
# [Đảo ngược key và value của dictionary]
# Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo một
# dictionary mới bằng cách đảo ngược key và value của dictionary ban đầu. In
# ra dictionary mới.

# %%
data=input().split()
kq={}
for i in range(0,len(data),2):
    key=data[i]
    value=data[i+1]  
    kq[value]=key 
print(kq)
# Out:
# {'10': '1', '20': '2'}

# %% [markdown]
# [Giao của hai danh sách]
# Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các
# phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các
# phần tử chung đó, không trùng lặp.

# %%
dict1=list(map(int,input().split()))
dict2=list(map(int,input().split()))
print(f"{list(set(dict1)&set(dict2))}")
# Out:
# [4, 5]

# %% [markdown]
# [Lọc dictionary theo giá trị]
# Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số
# nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp keyvalue từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary mới.

# %%
data=input().split()
k=int(input()) 
kq={}
for i in range(0,len(data),2):
    key=data[i]
    value=data[i+1] 
    value=int(value)
    if value>k: 
        kq[key]=value 
print(kq)
# Out:
# {'math': 95, 'english': 92}
